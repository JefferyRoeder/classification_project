# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score
from math import sqrt
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from scipy import stats
import graphviz
from graphviz import Graph

import env
import acquire
import split_scale
#import features
import prep
#import exploration
#import feature_selection
#import model

# %% [markdown]
# ### Acquisition and initial data exploration

# %%
df = acquire.prep_telco()

# %%
df = df[(df.internet_service_type_id !=3) & (df.contract_type_id!=1)]

df.describe().transpose()
# Out:
#                            count       mean        std   min    25%     50%  \
# senior_citizen            2166.0   0.136196   0.343076   0.0   0.00   0.000
# tenure                    2166.0  53.677285  17.813110   0.0  43.00  59.000
# internet_service_type_id  2166.0   1.446907   0.497288   1.0   1.00   1.000
# contract_type_id          2166.0   2.487996   0.499971   2.0   2.00   2.000
# payment_type_id           2166.0   2.762696   1.125400   1.0   2.00   3.000
# monthly_charges           2166.0  81.879132  21.865061  24.1  64.75  83.925
#
#                                75%     max
# senior_citizen              0.0000    1.00
# tenure                     69.0000   72.00
# internet_service_type_id    2.0000    2.00
# contract_type_id            3.0000    3.00
# payment_type_id             4.0000    4.00
# monthly_charges           100.6375  118.75

# %%
df.head()
# Out:
#    customer_id  gender  senior_citizen partner dependents  tenure  \
# 0   0002-ORFBO  Female               0     Yes        Yes       9
# 6   0013-SMEOE  Female               1     Yes         No      71
# 7   0014-BMAQU    Male               0     Yes         No      63
# 9   0016-QLJIS  Female               0     Yes        Yes      65
# 10  0017-DINOC    Male               0      No         No      54
#
#    phone_service    multiple_lines  internet_service_type_id online_security  \
# 0            Yes                No                         1              No
# 6            Yes                No                         2             Yes
# 7            Yes               Yes                         2             Yes
# 9            Yes               Yes                         1             Yes
# 10            No  No phone service                         1             Yes
#
#     ... device_protection tech_support streaming_tv streaming_movies  \
# 0   ...                No          Yes          Yes               No
# 6   ...               Yes          Yes          Yes              Yes
# 7   ...                No          Yes           No               No
# 9   ...               Yes          Yes          Yes              Yes
# 10  ...                No          Yes          Yes               No
#
#    contract_type_id  paperless_billing payment_type_id  monthly_charges  \
# 0                 2                Yes               2            65.60
# 6                 3                Yes               3           109.70
# 7                 3                Yes               4            84.65
# 9                 3                Yes               2            90.45
# 10                3                 No               4            45.20
#
#     total_charges churn
# 0           593.3    No
# 6         7904.25    No
# 7          5377.8    No
# 9          5957.9    No
# 10        2460.55    No
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Initial data prep
#
# Several fields needed to be cleaned up, converted to booleans, and combined.
#
# - Total charges had 13 blank values that were dropped from the dataset. That is too few records to significantly impact our analysis
#
#
# - churn, senior_citizen, gender, paperless_billing all converted to boolean values.
#
#
# - Combined fields: partner/dependents to family, phone_service/multiple_lines to phone, streaming_tv/streaming_movies to streaming, device_protection/tech_support to tech_protection, and online_backup/online_security to internet_security

# %%
df = prep.clean_telco(df)

# %% [markdown]
# ### Senior leadership questions and initial hypothesis
#
# Based on our current understanding of the business. We believe that churn is highly based on short tenured customers.
#
# Initial exploration included addressing the questions presented by the senior leadership to get an idea of what our data was telling us. As well as testing our initial hypothesis of tenure driving churn.

# %% [markdown]
# ##### Is there a month where a customer is more likely to churn?
#
# The scatterplot below shows customer tenure on the x axis and churn rate on the y axix.
#
# You can see a clear rise in churn rate for newer customers.

# %%
prep.tenure_churn(df)

# %% [markdown]
# ##### Is there a tenure that month to month are most likely to churn? 1 year contracts? 2 year contracts?
#
# The chart below shows the breakout of churn by contract type.
#
# Newer customers are still more likely to churn across the board but now we see that month to month contracts really stand out in the early months.
#
# There could be several factors driving this loss in early customers. They may be testing out our services and not enjoying the quality enough to stay. The competition could also be targeting our customers that are not locked into lengthy contracts. If we want to keep this contract type we need to address our onboarding process to ensure our new customers have the highest possible satisfaction in the first few weeks of using our services. It may help to incentivize our newer m2m customers to switch to 1 or 2 year contracts if possible

# %%
prep.contract_churn(df)

# %% [markdown]
# ##### Are there features that indicate a higher propensity to churn? Internet type? phone service? online security/backup? senior citizen? paying more than x% of customers?
#
#
# Internet type was a strong indicator of churn. Fiber and DSL customers were both more likely to churn than those with no internet.

# %%
prep.internet_churn(df)

# %% [markdown]
# Phone service was not a strong indicator of churn.

# %%
prep.phone_churn(df)
# Out:
#    phone  churn_rate
# 0  False    0.055921
# 1   True    0.098546

# %% [markdown]
# Customers without online security or online backup were significantly more likely to churn than those with it.

# %%
prep.security_churn(df)
# Out:
#   online_security  churn_rate
# 0              No    0.136259
# 1             Yes    0.063320

# %%
prep.backup_churn(df)
# Out:
#   online_backup  churn_rate
# 0            No    0.102628
# 1           Yes    0.086637

# %% [markdown]
# Seniors were somewhat more likely to churn.

# %%
prep.senior_churn(df)
# Out:
#    senior_citizen  churn_rate
# 0           False    0.088424
# 1            True    0.118644

# %% [markdown]
# ##### Is there a price threshold for specific services where the likelihood of churn increases once price for those services goes past that point?
#
# The data shows that there is not a clear price point where churn shifts dramatically.

# %%
prep.charges_churn(df)

# %% [markdown]
# The below chart shows that our highest churning customers are also bringing in the most revenue. We need to work to upsell our stable and lower tier customers to better service packages.

# %%
prep.charges_distro(df)

# %%
prep.quantile_churn(df)
# Out:
# Customers churned at an average rate of:  9.3 %
# Customers in the top 25% of monthly charges churned at a rate of:  24.942156409069874 %
# Customers in the bottom 25% of monthly charges churned at a rate of:  24.988431281813973 %

# %% [markdown]
# ### Data prep
#
# - Converting churn and senior citizen to boolean.
# - Combining partner and dependents into one variable called 'family' if either column is Yes.
# - Combining phone_service and multiple_lines into one variable called phone if either column is Yes.

# %%
df = prep.drop_columns(df)

# %% [markdown]
# #### Split and Scale

# %%
train, test = split_scale.split_my_data(df,train_ratio=.8,seed=123,stratify=None)

# %% [markdown]
# #### Create X and y train/test

# %%
X_train = train.drop(['churn'],axis=1)
y_train = train.churn
X_test = test.drop(['churn'],axis=1)
y_test = test.churn

# %% [markdown]
# #### Fit model to training data

# %%
clf = DecisionTreeClassifier(criterion='entropy',max_depth=4,random_state=123)

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=4,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=123, splitter='best')

# %%
y_pred = clf.predict(X_train)

# %%
y_pred_prob = clf.predict_proba(X_train)
y_pred_prob
# Out:
# array([[0.9939759 , 0.0060241 ],
#        [0.9939759 , 0.0060241 ],
#        [0.9939759 , 0.0060241 ],
#        ...,
#        [0.94736842, 0.05263158],
#        [0.88700565, 0.11299435],
#        [0.82716049, 0.17283951]])

# %%
prep.model_accuracy(X_train,y_train,X_test,y_test,clf)
# Out:
# The train data had an accuracy of:  0.9056712962962963
# The test data had an accuracy of:  0.9214780600461894

# %% [markdown]
# We have a prediction accuracy rate of 79%. This is a solid score for a baseline model but I believe with a bit of tweaking to the model we can improve.

# %% [markdown]
# The confusion matrix below shows that we are struggling a bit with type 1 and type 2 errors, incorrectly marking customers we deem likely to churn and stayed. As well as those that will churn that we are not identifying. This is something we will work on in future models.

# %%
confusion_matrix(y_train,y_pred)
# Out:
# array([[1561,    0],
#        [ 163,    4]])

# %% [markdown]
# The below chart shows that we are far more precise predicting those that will not churn.

# %%
print(classification_report(y_train,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.70      0.67      0.68      1415
#         True       0.65      0.68      0.66      1265
#
#     accuracy                           0.67      2680
#    macro avg       0.67      0.67      0.67      2680
# weighted avg       0.67      0.67      0.67      2680

# %% [markdown]
# A breakdown of the decision tree for the baseline model.

# %%
# dot_data = export_graphviz(clf,out_file=None)
# graph = graphviz.Source(dot_data)
# graph.render('telco_churn',view=True)
X_train
# Out:
#              senior_citizen  tenure  internet_service_type_id  \
# customer_id
# 9739-JLPQJ            False      72                         2
# 3162-KKZXO             True      55                         2
# 8920-NAVAY             True      62                         2
# 4043-MKDTV            False      71                         2
# 7632-MNYOY             True      66                         2
# 1017-FBQMM            False      62                         2
# 8952-WCVCD            False      41                         2
# 4692-NNQRU            False      21                         2
# 8849-GYOKR            False      54                         2
# 9386-LDCZR            False      43                         2
# 9138-EFSMO            False      26                         2
# 6993-YGFJV            False      69                         2
# 3733-UOCWF             True      61                         2
# 6734-FQAJX             True      67                         2
# 5649-VUKMC            False      12                         2
# 4024-CSNBY            False      72                         2
# 6295-OSINB            False      72                         2
# 2748-MYRVK            False      63                         2
# 0164-APGRB            False      72                         2
# 3571-DPYUH            False      58                         2
# 9762-YAQAA            False      39                         2
# 0750-EBAIU            False      52                         2
# 5996-NRVXR             True      40                         2
# 4118-CEVPF             True      35                         2
# 5056-FIMPT            False      43                         2
# 0580-PIQHM            False      41                         2
# 7064-FRRSW             True      48                         2
# 8024-XNAFQ             True      72                         2
# 3766-EJLFL            False      68                         2
# 1480-BKXGA             True      72                         2
# ...                     ...     ...                       ...
# 0691-NIKRI            False      40                         2
# 2193-SFWQW            False      72                         2
# 6308-CQRBU            False      71                         2
# 4393-RYCRE            False      44                         2
# 2578-JQPHZ            False      44                         2
# 8777-MBMTS             True      65                         2
# 3511-APPBJ            False      23                         2
# 4323-OHFOW             True      70                         2
# 1135-HIORI            False      64                         2
# 2294-SALNE            False      23                         2
# 9770-KXGQU            False      53                         2
# 5651-CRHKQ            False      41                         2
# 0748-RDGGM            False      70                         2
# 0479-HMSWA            False      26                         2
# 6617-WLBQC            False      23                         2
# 1150-FTQGN            False      60                         2
# 1004-NOZNR             True      56                         2
# 7607-QKKTJ            False      45                         2
# 2239-JALAW            False      58                         2
# 5914-XRFQB            False      72                         2
# 1265-XTECC             True      68                         2
# 1095-WGNGG            False      61                         2
# 6234-RAAPL            False      72                         2
# 0197-PNKNK            False      69                         2
# 7661-CPURM            False      19                         2
# 1024-KPRBB            False      38                         2
# 3301-VKTGC            False      68                         2
# 3927-NLNRY            False      53                         2
# 3756-VNWDH             True      65                         2
# 5294-IMHHT            False      53                         2
#
#              contract_type_id  paperless_billing  payment_type_id  \
# customer_id
# 9739-JLPQJ                  3              False                4
# 3162-KKZXO                  2               True                1
# 8920-NAVAY                  2               True                3
# 4043-MKDTV                  3               True                1
# 7632-MNYOY                  2              False                4
# 1017-FBQMM                  2               True                4
# 8952-WCVCD                  2               True                3
# 4692-NNQRU                  2              False                1
# 8849-GYOKR                  2              False                3
# 9386-LDCZR                  2               True                4
# 9138-EFSMO                  2              False                3
# 6993-YGFJV                  3               True                3
# 3733-UOCWF                  2               True                3
# 6734-FQAJX                  3               True                1
# 5649-VUKMC                  2              False                2
# 4024-CSNBY                  3               True                3
# 6295-OSINB                  3               True                1
# 2748-MYRVK                  2              False                3
# 0164-APGRB                  3               True                1
# 3571-DPYUH                  2               True                4
# 9762-YAQAA                  2              False                4
# 0750-EBAIU                  2              False                1
# 5996-NRVXR                  2               True                4
# 4118-CEVPF                  2               True                3
# 5056-FIMPT                  2               True                4
# 0580-PIQHM                  2               True                3
# 7064-FRRSW                  2               True                1
# 8024-XNAFQ                  3               True                3
# 3766-EJLFL                  3               True                3
# 1480-BKXGA                  3               True                3
# ...                       ...                ...              ...
# 0691-NIKRI                  2               True                4
# 2193-SFWQW                  3              False                3
# 6308-CQRBU                  3              False                1
# 4393-RYCRE                  2               True                1
# 2578-JQPHZ                  3              False                3
# 8777-MBMTS                  3               True                4
# 3511-APPBJ                  2               True                4
# 4323-OHFOW                  2               True                3
# 1135-HIORI                  2               True                1
# 2294-SALNE                  2              False                2
# 9770-KXGQU                  2              False                2
# 5651-CRHKQ                  2               True                3
# 0748-RDGGM                  2               True                3
# 0479-HMSWA                  3               True                1
# 6617-WLBQC                  2              False                4
# 1150-FTQGN                  2              False                3
# 1004-NOZNR                  2              False                4
# 7607-QKKTJ                  2               True                4
# 2239-JALAW                  2               True                3
# 5914-XRFQB                  3               True                3
# 1265-XTECC                  2               True                4
# 1095-WGNGG                  3               True                3
# 6234-RAAPL                  3              False                3
# 0197-PNKNK                  2              False                3
# 7661-CPURM                  2               True                4
# 1024-KPRBB                  2               True                2
# 3301-VKTGC                  2               True                3
# 3927-NLNRY                  2               True                3
# 3756-VNWDH                  2               True                1
# 5294-IMHHT                  2              False                3
#
#              monthly_charges  total_charges  is_male  family  phone  \
# customer_id
# 9739-JLPQJ            117.50        8670.10    False    True   True
# 3162-KKZXO            100.15        5409.75    False   False   True
# 8920-NAVAY            110.75        7053.35     True   False   True
# 4043-MKDTV            105.25        7291.75     True    True   True
# 7632-MNYOY            110.90        7432.05     True   False   True
# 1017-FBQMM            106.05        6703.50    False    True   True
# 8952-WCVCD            104.45        4162.05    False    True   True
# 4692-NNQRU             79.20        1742.45    False    True   True
# 8849-GYOKR            106.55        5763.30    False    True   True
# 9386-LDCZR             90.65        3882.30     True   False   True
# 9138-EFSMO             78.95        2034.25     True    True   True
# 6993-YGFJV            112.55        7806.50     True    True   True
# 3733-UOCWF             85.55        5251.75     True    True   True
# 6734-FQAJX            105.05        7171.70     True   False   True
# 5649-VUKMC             95.50        1115.15    False   False   True
# 4024-CSNBY             94.25        6849.75    False    True   True
# 6295-OSINB            109.65        7880.25     True    True   True
# 2748-MYRVK             99.90        6137.00    False   False   True
# 0164-APGRB            114.90        8496.70    False   False   True
# 3571-DPYUH             94.70        5430.35     True    True   True
# 9762-YAQAA             81.40        3213.75     True   False   True
# 0750-EBAIU             91.25        4738.30     True   False   True
# 5996-NRVXR             98.15        4116.80     True    True   True
# 4118-CEVPF            110.80        3836.30    False   False   True
# 5056-FIMPT            106.00        4532.30    False    True   True
# 0580-PIQHM            101.60        3930.55    False    True   True
# 7064-FRRSW             99.00        4744.35     True   False   True
# 8024-XNAFQ            107.40        7748.75    False   False   True
# 3766-EJLFL            109.05        7508.55    False    True   True
# 1480-BKXGA            116.05        8404.90     True    True   True
# ...                      ...            ...      ...     ...    ...
# 0691-NIKRI            105.95        4335.20    False   False   True
# 2193-SFWQW            111.95        8033.10     True    True   True
# 6308-CQRBU            109.25        7707.70    False    True   True
# 4393-RYCRE            106.05        4510.80     True   False   True
# 2578-JQPHZ            100.10        4378.35     True   False   True
# 8777-MBMTS            105.85        6725.50    False    True   True
# 3511-APPBJ             99.95        2292.75     True   False   True
# 4323-OHFOW            105.55        7195.35    False    True   True
# 1135-HIORI            111.45        7266.95    False    True   True
# 2294-SALNE             86.80        1940.80     True    True   True
# 9770-KXGQU             98.60        5311.85    False   False   True
# 5651-CRHKQ             86.20        3339.05    False    True   True
# 0748-RDGGM            109.50        7534.65     True    True   True
# 0479-HMSWA            105.45        2715.30    False    True   True
# 6617-WLBQC             81.85        1810.85    False    True   True
# 1150-FTQGN             94.15        5811.80    False    True   True
# 1004-NOZNR             94.80        5264.30     True    True   True
# 7607-QKKTJ             95.00        4368.85     True    True   True
# 2239-JALAW            103.25        6017.65     True   False   True
# 5914-XRFQB            115.80        8424.90     True    True   True
# 1265-XTECC             96.55        6581.90    False    True   True
# 1095-WGNGG            101.05        5971.25    False    True   True
# 6234-RAAPL             99.90        7251.70    False    True   True
# 0197-PNKNK             84.45        5848.60    False    True   True
# 7661-CPURM             87.70        1725.95     True   False   True
# 1024-KPRBB             89.10        3342.00    False   False   True
# 3301-VKTGC             85.50        5696.60     True    True   True
# 3927-NLNRY             94.25        4867.95     True    True   True
# 3756-VNWDH            100.75        6674.65     True    True   True
# 5294-IMHHT             97.75        5043.20     True    True   True
#
#              streaming  tech_protection  internet_security
# customer_id
# 9739-JLPQJ        True             True               True
# 3162-KKZXO        True             True              False
# 8920-NAVAY        True             True               True
# 4043-MKDTV        True             True               True
# 7632-MNYOY        True             True               True
# 1017-FBQMM        True             True               True
# 8952-WCVCD        True             True               True
# 4692-NNQRU       False             True              False
# 8849-GYOKR        True            False               True
# 9386-LDCZR       False             True               True
# 9138-EFSMO        True            False              False
# 6993-YGFJV        True             True               True
# 3733-UOCWF       False             True               True
# 6734-FQAJX        True             True               True
# 5649-VUKMC        True             True              False
# 4024-CSNBY       False             True               True
# 6295-OSINB        True             True               True
# 2748-MYRVK        True            False               True
# 0164-APGRB        True             True               True
# 3571-DPYUH        True             True               True
# 9762-YAQAA       False            False               True
# 0750-EBAIU        True             True               True
# 5996-NRVXR        True             True               True
# 4118-CEVPF        True             True               True
# 5056-FIMPT        True             True               True
# 0580-PIQHM        True             True               True
# 7064-FRRSW        True            False               True
# 8024-XNAFQ        True             True               True
# 3766-EJLFL        True             True               True
# 1480-BKXGA        True             True               True
# ...                ...              ...                ...
# 0691-NIKRI        True             True              False
# 2193-SFWQW        True             True               True
# 6308-CQRBU        True             True               True
# 4393-RYCRE        True             True               True
# 2578-JQPHZ        True             True              False
# 8777-MBMTS        True             True               True
# 3511-APPBJ        True             True               True
# 4323-OHFOW        True             True               True
# 1135-HIORI        True             True               True
# 2294-SALNE       False             True               True
# 9770-KXGQU        True             True               True
# 5651-CRHKQ       False             True               True
# 0748-RDGGM        True             True               True
# 0479-HMSWA        True             True               True
# 6617-WLBQC       False            False               True
# 1150-FTQGN        True            False               True
# 1004-NOZNR        True            False               True
# 7607-QKKTJ        True             True               True
# 2239-JALAW        True             True               True
# 5914-XRFQB        True             True               True
# 1265-XTECC        True            False               True
# 1095-WGNGG        True            False               True
# 6234-RAAPL        True             True               True
# 0197-PNKNK       False             True               True
# 7661-CPURM        True             True              False
# 1024-KPRBB        True            False              False
# 3301-VKTGC       False            False               True
# 3927-NLNRY        True            False               True
# 3756-VNWDH        True            False               True
# 5294-IMHHT        True             True               True
#
# [774 rows x 14 columns]

# %% [markdown]
# The below table shows our scored features from the baseline model. contract type, monthly charges, and tenure were the strongest features with a few other minor drivers. Quite a few of our features provided no value. This information will be taken into account when working on the mvp.

# %%
prep.key_features(clf,X_train)
# Out:
#                            0       1
# 0            monthly_charges  0.3511
# 1                     tenure  0.2845
# 2              total_charges  0.1310
# 3           contract_type_id  0.1014
# 4            payment_type_id  0.0675
# 5                  streaming  0.0645
# 6             senior_citizen  0.0000
# 7   internet_service_type_id  0.0000
# 8          paperless_billing  0.0000
# 9                    is_male  0.0000
# 10                    family  0.0000
# 11                     phone  0.0000
# 12           tech_protection  0.0000
# 13         internet_security  0.0000

# %%
predictions_df = pd.concat([X_train,X_test])

# %%
y_pred_prob = clf.predict_proba(predictions_df)
y_pred_prob
# Out:
# array([[1.        , 0.        ],
#        [0.82323232, 0.17676768],
#        [0.70344828, 0.29655172],
#        ...,
#        [0.96      , 0.04      ],
#        [0.70344828, 0.29655172],
#        [0.96      , 0.04      ]])

# %%
y_predictions = pd.DataFrame({'probability_of_churn': y_pred_prob[:,1],'churned':(y_pred_prob[:,1] >=.5) == 1})

y_predictions = y_predictions.set_index(df.index)

# %%
y_predictions.to_csv(r'churn_probability_predictions.csv')

# %% [markdown]
# #### Conclusion
#
# After initial exploration, analysis, and modeling we have a much stronger understanding of the factors driving churn. We know that contract type, tenure, and services received are strong drivers.
#
# - As a company we need to address the flight of fiber customers. We could do this with promotion programs and addressing quality issues within our fiber product.
#
# - New customers are also churning at a much higher rate. I believe we can address this with incentive programs to shift them to 6mo or 1year contracts at a discounted rate as well as potentially implementing a cancelation fee to disincentivize leaving.
#
# -
